# %%
import pandas as pd

# %%
# to read a csv file
df = pd.read_csv('countries of the world.csv')

# using read_table
#df = pd.read_table('countries of the world.csv', sep = ',')

# %%
# to read a txt file
# using read_csv
#df1 = pd.read_csv('countries of the world.txt', sep = '\t')

# using read_table
df1 = pd.read_table('countries of the world.txt')

# %%
# to read JSON file
df2 = pd.read_json('json_sample.json')

# %%
# to read excel file
df3 = pd.read_excel('world_population_excel_workbook.xlsx')

# to read other than default or first sheet from excel
df3 = pd.read_excel('world_population_excel_workbook.xlsx', sheet_name = 'Sheet1')

# %%
# to set display option of output
pd.set_option('display.max.rows',235)
pd.set_option('display.max.columns',40)

# %%
# Looking at Data: Dtype, NULL values and memory usage
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    object
#  2   Country  234 non-null    object
#  3   Capital  234 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.4+ KB

# %%
df3.shape
# Out:
# (234, 4)

# %%
# to gave first 5 or mentioned rows
df3.head()
# Out:
#    Rank CCA3         Country           Capital
# 0    36  AFG     Afghanistan             Kabul
# 1   138  ALB         Albania            Tirana
# 2    34  DZA         Algeria           Algiers
# 3   213  ASM  American Samoa         Pago Pago
# 4   203  AND         Andorra  Andorra la Vella

# %%
# to gave last 5 or mentioned columns
df3.tail()
# Out:
#      Rank CCA3            Country    Capital
# 229   226  WLF  Wallis and Futuna   Mata-Utu
# 230   172  ESH     Western Sahara  El Aai̼n
# 231    46  YEM              Yemen      Sanaa
# 232    63  ZMB             Zambia     Lusaka
# 233    74  ZWE           Zimbabwe     Harare

# %%
# to see or oberver specific column in dataframe
# df3['Rank'] ## single column
df3[['Rank','Country']] ## more than 1 column
# Out:
#      Rank                           Country
# 0      36                       Afghanistan
# 1     138                           Albania
# 2      34                           Algeria
# 3     213                    American Samoa
# 4     203                           Andorra
# 5      42                            Angola
# 6     224                          Anguilla
# 7     201               Antigua and Barbuda
# 8      33                         Argentina
# 9     140                           Armenia
# 10    198                             Aruba
# 11     55                         Australia
# 12     99                           Austria
# 13     91                        Azerbaijan
# 14    176                           Bahamas
# 15    154                           Bahrain
# 16      8                        Bangladesh
# 17    186                          Barbados
# 18     96                           Belarus
# 19     81                           Belgium
# ...

# %%
# to retrive data on the basis of index
df3.loc[224]  ## work on non-integer indexes also
# Out:
# Rank               43
# CCA3              UZB
# Country    Uzbekistan
# Capital      Tashkent
# Name: 224, dtype: object

# %%
df3.iloc[224]  ## work on only integer indexes also
# Out:
# Rank               43
# CCA3              UZB
# Country    Uzbekistan
# Capital      Tashkent
# Name: 224, dtype: object
